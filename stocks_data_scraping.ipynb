# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import WebDriverException
import time
import pandas as pd

# Initialize WebDriver
driver = webdriver.Chrome()  # You can replace Chrome with Firefox or other supported browsers

# Initialize an empty list to store the extracted data
all_data = []

# Define the base URL and the total number of pages
base_url = "https://www.mubasher.info/news/sa/pulse/stocks/"
total_pages = 219  # Replace this with the total number of pages

# Loop through each page and extract data
for page_num in range(1, total_pages + 1):
    # Construct the URL for the current page
    page_url = f"{base_url}{page_num}"
    
    # Open the webpage with a retry mechanism
    max_retries = 3
    for retry in range(max_retries):
        try:
            driver.get(page_url)
            break  # Exit loop on successful load
        except WebDriverException as e:
            if retry == max_retries - 1:
                raise e  # Raise the error on the last retry
            print(f"Retry {retry + 1}/{max_retries} due to: {e}")
        time.sleep(3)  # Wait between retries
    
    # Wait for the page to load
    driver.implicitly_wait(10)  # Adjust the wait time as needed
    
    # Find and extract the desired information
    articles = driver.find_elements(By.CLASS_NAME, "mi-article-media-block__content")
    for article in articles:
        title_element = article.find_element(By.CLASS_NAME, "mi-article-media-block__title")
        title = title_element.text.strip()

        date_element = article.find_element(By.CLASS_NAME, "mi-article-media-block__date")
        date = date_element.text.strip()

        tag_elements = article.find_elements(By.CLASS_NAME, "label")
        tag = tag_elements[0].text.strip() if tag_elements else "N/A"  # Use "N/A" if the tag is not found

        all_data.append({"Title": title, "Date": date, "Tag": tag})
        
    # Print progress
    print(f"Page {page_num}/{total_pages} done")
    
# Close the WebDriver
driver.quit()

# Create a DataFrame from the extracted data
df = pd.DataFrame(all_data)

# Save the DataFrame to a CSV file
csv_filename = "news_data.csv"
df.to_csv(csv_filename, index=False)

print("Data saved to", csv_filename)
# Out:
# Page 1/219 done
# Page 2/219 done
# Page 3/219 done
# Page 4/219 done
# Page 5/219 done
# Page 6/219 done
# Page 7/219 done
# Page 8/219 done
# Page 9/219 done
# Page 10/219 done
# Page 11/219 done
# Page 12/219 done
# Page 13/219 done
# Page 14/219 done
# Page 15/219 done
# Page 16/219 done
# Page 17/219 done
# Page 18/219 done
# Page 19/219 done
# Page 20/219 done
# Page 21/219 done
# Page 22/219 done
# Page 23/219 done
# Page 24/219 done
# Page 25/219 done
# Page 26/219 done
# Page 27/219 done
# Page 28/219 done
# Page 29/219 done
# Page 30/219 done
# Page 31/219 done
# Page 32/219 done
# Page 33/219 done
# Page 34/219 done
# Page 35/219 done
# Page 36/219 done
# Page 37/219 done
# Page 38/219 done
# Page 39/219 done
# Page 40/219 done
# Page 41/219 done
# Page 42/219 done
# Page 43/219 done
# Page 44/219 done
# Page 45/219 done
# Page 46/219 done
# Page 47/219 done
# Page 48/219 done
# Page 49/219 done
# Page 50/219 done
# Page 51/219 done
# Page 52/219 done
# Page 53/219 done
# Page 54/219 done
# Page 55/219 done
# Page 56/219 done
# Page 57/219 done
# Page 58/219 done
# Page 59/219 done
# Page 60/219 done
# Page 61/219 done
# Page 62/219 done
# Page 63/219 done
# Page 64/219 done
# Page 65/219 done
# Page 66/219 done
# Page 67/219 done
# Page 68/219 done
# Page 69/219 done
# Page 70/219 done
# Page 71/219 done
# Page 72/219 done
# Page 73/219 done
# Page 74/219 done
# Page 75/219 done
# Page 76/219 done
# Page 77/219 done
# Page 78/219 done
# Page 79/219 done
# Page 80/219 done
# Page 81/219 done
# Page 82/219 done
# Page 83/219 done
# Page 84/219 done
# Page 85/219 done
# Page 86/219 done
# Page 87/219 done
# Page 88/219 done
# Page 89/219 done
# Page 90/219 done
# Page 91/219 done
# Page 92/219 done
# Page 93/219 done
# Page 94/219 done
# Page 95/219 done
# Page 96/219 done
# Page 97/219 done
# Page 98/219 done
# Page 99/219 done
# Page 100/219 done
# Page 101/219 done
# Page 102/219 done
# Page 103/219 done
# Page 104/219 done
# Page 105/219 done
# Page 106/219 done
# Page 107/219 done
# Page 108/219 done
# Page 109/219 done
# Page 110/219 done
# Page 111/219 done
# Page 112/219 done
# Page 113/219 done
# Page 114/219 done
# Page 115/219 done
# Page 116/219 done
# Page 117/219 done
# Page 118/219 done
# Page 119/219 done
# Page 120/219 done
# Page 121/219 done
# Page 122/219 done
# Page 123/219 done
# Page 124/219 done
# Page 125/219 done
# Page 126/219 done
# Page 127/219 done
# Page 128/219 done
# Page 129/219 done
# Page 130/219 done
# Page 131/219 done
# Page 132/219 done
# Page 133/219 done
# Page 134/219 done
# Page 135/219 done
# Page 136/219 done
# Page 137/219 done
# Page 138/219 done
# Page 139/219 done
# Page 140/219 done
# Page 141/219 done
# Page 142/219 done
# Page 143/219 done
# Page 144/219 done
# Page 145/219 done
# Page 146/219 done
# Page 147/219 done
# Page 148/219 done
# Page 149/219 done
# Page 150/219 done
# Page 151/219 done
# Page 152/219 done
# Page 153/219 done
# Page 154/219 done
# Page 155/219 done
# Page 156/219 done
# Page 157/219 done
# Page 158/219 done
# Page 159/219 done
# Page 160/219 done
# Page 161/219 done
# Page 162/219 done
# Page 163/219 done
# Page 164/219 done
# Page 165/219 done
# Page 166/219 done
# Page 167/219 done
# Page 168/219 done
# Page 169/219 done
# Page 170/219 done
# Page 171/219 done
# Page 172/219 done
# Page 173/219 done
# Page 174/219 done
# Page 175/219 done
# Page 176/219 done
# Page 177/219 done
# Page 178/219 done
# Page 179/219 done
# Page 180/219 done
# Page 181/219 done
# Page 182/219 done
# Page 183/219 done
# Page 184/219 done
# Page 185/219 done
# Page 186/219 done
# Page 187/219 done
# Page 188/219 done
# Page 189/219 done
# Page 190/219 done
# Page 191/219 done
# Page 192/219 done
# Page 193/219 done
# Page 194/219 done
# Page 195/219 done
# Page 196/219 done
# Page 197/219 done
# Page 198/219 done
# Page 199/219 done
# Page 200/219 done
# Page 201/219 done
# Page 202/219 done
# Page 203/219 done
# Page 204/219 done
# Page 205/219 done
# Page 206/219 done
# Page 207/219 done
# Page 208/219 done
# Page 209/219 done
# Page 210/219 done
# Page 211/219 done
# Page 212/219 done
# Page 213/219 done
# Page 214/219 done
# Page 215/219 done
# Page 216/219 done
# Page 217/219 done
# Page 218/219 done
# Page 219/219 done
# Data saved to news_data.csv

# %%
aa = pd.read_csv('news_data.csv')

# %%
aa
# Out:
#                                                   Title                  Date  \
# 0     خسائر "معدنية" ترتفع 7.8% إلى 7.56 مليون ريال....             منذ لحظات
# 1     "أنابيب" تفوز بعقد من "أرامكو السعودية" بقيمة ...          34 دقائق مضت
# 2     "البحري" تمدد مذكرة مع "مجموعة عجلان" لبحث إنش...          48 دقائق مضت
# 3     لجنة المنازعات الزكوية تلزم "جبل عمر" بتسديد 3...          53 دقائق مضت
# 4     "أليانز" تتحول للربحية بـ 13.16 مليون ريال خلا...            1 ساعة مضت
# ...                                                 ...                   ...
# 5449  19 أبريل.. مساهمو "أنعام القابضة" يناقشون زياد...  27 مارس 2022 09:53 ص
# 5450  "المعمر": ترسية مشروع مع وزارة المياه والزراعة...  27 مارس 2022 09:51 ص
# 5451  المنافسة تقر عملية التركز الاقتصادي لاستحواذ "...  27 مارس 2022 09:46 ص
# 5452  " دار الأركان" توقع عقداً مع "عمران" العمانية ...  27 مارس 2022 09:40 ص
# 5453  "مجموعة تداول":زيادة المقابل المالي لعمولات تد...  27 مارس 2022 09:24 ص
#
#                       Tag
# 0     نتائج أعمال الشركات
# 1            أخبار الشركة
# 2       استثمارات الشركات
# 3                   ضرائب
# 4     نتائج أعمال الشركات
# ...                   ...
# 5449        جمعيات عمومية
# 5450         أخبار الشركة
# 5451  اندماجات واستحواذات
# 5452         أخبار الشركة
# 5453         أخبار الشركة
#
# [5454 rows x 3 columns]
